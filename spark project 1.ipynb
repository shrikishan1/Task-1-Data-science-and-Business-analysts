# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("C:/Users/shrikishan soni/OneDrive/Desktop/spark internship/Iris.csv")
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.drop(["Species","Id"],axis="columns")
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
from sklearn.cluster import KMeans
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
cls = KMeans(n_clusters = 2, )
cls.fit(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-5f5e07fa7cfd> in <module>
#       1 cls = KMeans(n_clusters = 2, )
# ----> 2 cls.fit(data)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in fit(self, X, y, sample_weight)
#     989             )
#     990
# --> 991         X = self._validate_data(X, accept_sparse='csr',
#     992                                 dtype=[np.float64, np.float32],
#     993                                 order='C', copy=self.copy_x,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     418                     f"requires y to be passed, but the target y is None."
#     419                 )
# --> 420             X = check_array(X, **check_params)
#     421             out = X
#     422         else:
#
# ...

# %%
y_kmeans = cls.fit_predict(data)
cls.cluster_centers_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-1fbca58d513e> in <module>
# ----> 1 y_kmeans = cls.fit_predict(data)
#       2 cls.cluster_centers_
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in fit_predict(self, X, y, sample_weight)
#    1103             Index of the cluster each sample belongs to.
#    1104         """
# -> 1105         return self.fit(X, sample_weight=sample_weight).labels_
#    1106
#    1107     def fit_transform(self, X, y=None, sample_weight=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in fit(self, X, y, sample_weight)
#     989             )
#     990
# --> 991         X = self._validate_data(X, accept_sparse='csr',
#     992                                 dtype=[np.float64, np.float32],
#     993                                 order='C', copy=self.copy_x,
#
# ...

# %%
data['cluster']=  KMeans
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#                                     cluster
# 0  <class 'sklearn.cluster._kmeans.KMeans'>
# 1  <class 'sklearn.cluster._kmeans.KMeans'>
# 2  <class 'sklearn.cluster._kmeans.KMeans'>
# 3  <class 'sklearn.cluster._kmeans.KMeans'>
# 4  <class 'sklearn.cluster._kmeans.KMeans'>

# %%
bestfeature=SelectKBest(score_func=chi2,k=5)

# %%
fit=bestfeature.fit(x,y)

# %%
datascores=pd.DataFrame(fit.scores_)
datacolumns=pd.DataFrame(x.columns)

# %%
featureScores=pd.concat([datacolumns,datascores],axis=1)
featureScores
# Out:
#                0            0
# 0             Id  3311.258278
# 1  SepalLengthCm    10.817821
# 2   SepalWidthCm     3.594499
# 3  PetalLengthCm   116.169847
# 4   PetalWidthCm    67.244828

# %%
featureScores.columns=["specs","score"]
sub_data=featureScores.nlargest(10,"score")
sub_data
# Out:
#            specs        score
# 0             Id  3311.258278
# 3  PetalLengthCm   116.169847
# 4   PetalWidthCm    67.244828
# 1  SepalLengthCm    10.817821
# 2   SepalWidthCm     3.594499

# %%
cols=sub_data.specs.to_list()
cols=cols+["Species"]

data1=data[cols]
data1
# Out:
#       Id  PetalLengthCm  PetalWidthCm  SepalLengthCm  SepalWidthCm  \
# 0      1            1.4           0.2            5.1           3.5
# 1      2            1.4           0.2            4.9           3.0
# 2      3            1.3           0.2            4.7           3.2
# 3      4            1.5           0.2            4.6           3.1
# 4      5            1.4           0.2            5.0           3.6
# ..   ...            ...           ...            ...           ...
# 145  146            5.2           2.3            6.7           3.0
# 146  147            5.0           1.9            6.3           2.5
# 147  148            5.2           2.0            6.5           3.0
# 148  149            5.4           2.3            6.2           3.4
# 149  150            5.1           1.8            5.9           3.0
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...
